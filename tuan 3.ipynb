# %% [markdown]
# # W3A1: Viết một chương trình nhập vào một số nguyên n và in ra các chữ số đảo ngược nhau.

# %%
n = int(input())
n = str(n)
daonguoc = n[::-1]
print(daonguoc)
# Out:
# 1

# %% [markdown]
# # W3A2:Hoán đổi hai số không sd biến tạm thời. Sử dụng phép toán XOR bitwise để hoán đổi giá trị của hai biến.

# %%
a, b = map(int, input().split())
a ^= b
b = a ^ b
a ^= b
print(a, b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 a, b = map(int, input().split())
#       2 a ^= b
#       3 b = a ^ b
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# # W3A3: Kiểm tra xem một số có phải là lũy thừa của 2 hay không . Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không. Gợi ý: Đối với lũy thừa của 2, n & (n-1) == 0

# %%
n = int(input())
if n & (n - 1) == 0:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# # W3A4: viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
m, n = map(int, input().split())
kq = m // n
print(kq)
# Out:
# 1

# %% [markdown]
# # W3A5: viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên

# %%
m, n = map(int, input().split())
if m % n == 0:
    print(m / n)
else:
    print(m // n + 1)
# Out:
# 1

# %% [markdown]
# # W3A6: Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ. Nếu x là số chẵn, in ra "Even". Nếu x là số lẻ, in ra "Odd".

# %%
x = int(input())
if x % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# # W3A7: Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No".

# %%
a, b = map(int,input().split())
if a < 0 and b < 0:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %% [markdown]
# # W3A8: Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False".

# %%
a, b = input().split()
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# # W3A9: Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không. Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No".

# %%
a, b ,c = map(int, input().split())
if a + b > c and a + c > b and b + c > a:
    print("YES")
else:
    print("NO")
# Out:
# NO

# %% [markdown]
# # W3A10: Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.

# %%
a, b, c, d = map(int, input().split())
t = max(max(a, b), max(c, d))
print(t)
# Out:
# 4

# %% [markdown]
# # W2A11: lệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay "Tam giác thường

# %%
a, b, c = map(int, input().split())
if a > 0 and b >0 and c > 0 and a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("tam giác đều")
    elif a == b or b == c or c == a:
        print("tam giác cân")
    else:
        print("tam giác thường")
else:
    print("không phải tam giác")
# Out:
# tam giác thường

# %% [markdown]
# # W3A12: Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"

# %%
n = int(input())
if (n % 4 == 0 and n % 100 != 0) or n % 400 == 0:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# # bài13: Nhập vào số kWh điện tiêu thụ. Tính tiền điện theo các bậc sau:
# # - 0-50 kWh: 1500đ/kWh
# # - 51-100 kWh: 2000đ/kWh
# # - 100 kWh: 3000đ/kWh

# %%
n = int(input())
if 0 <= n <= 50:
    tđ = 1500 * n
elif 50 < n < 100:
    tđ = 2000 * n
else:
    tđ = 3000 * n
print(tđ)
# Out:
# 75000

# %% [markdown]
# # bài14: Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số thập phân thứ 2. In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng.

# %%
a, b = map(float, input().split())
if a == 0 and b != 0:
    print("vô nghiệm")
elif a == 0 and b == 0:
    print("vô số nghiệm")
else:
    x = round(-b / a,2)
    print(x)
# Out:
# vô nghiệm

# %% [markdown]
# ### bài15:Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. Xếp loại học lực theo quy tắc:
# - >= 8.0: Giỏi
# - >= 6.5: Khá
# - >= 5.0: Trung bình
# - < 5.0: Yếu

# %%
diem_tb = float(input())
if diem_tb >= 8:
    print("giỏi")
elif diem_tb >= 6.5:
    print("khá")
elif diem_tb >= 5:
    print("trung bình")
else:
    print("yếu")
# Out:
# trung bình

# %% [markdown]
# # bài16: Nhập vào một số thực: in ra kết quả làm tròn lên ,tròn xuống, làm tròn tới số nguyên gần nhất (không được sử dụng hàm sẵn có của pyton). Các kết quả cách nhau một dấu cách

# %%
n = float(input())
t = (n == int(n))
print(t)
# Out:
# False

# %%
n = float(input())
# ktra n có phải số nguyên k
d = n == int(n)  
# làm tròn lên             
if d:                        
    l = int(n)
else:
    if n > 0:
        l = int(n) + 1
    else:
        l = int(n)
# làm tròn xuống
if d:
    x = int(n)
else:
    if n > 0:
        x = int(n)
    else:
        x = int(n) - 1
# làm tròn đến số gần nhất
if n < 0 and (n - int(n) == -0.5):
    g = int(n) - 1
else:
    if n > 0:
        g = int(n + 0.5)
    else:
        g = int(n - 0.5)
print(l , x, g)
# Out:
# -5 -6 -6

# %% [markdown]
# # bài17: Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1 cấp số nhân với công bội nguyên theo đúng thứ tự a, b, c, d hay không?
# # Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a, sau đó lấy b nhân công bội và so sánh vs c, c nhân công bội và so sánh vs d

# %%
a, b, c, d = map(int, input().split())
cb = b / a
if b * cb == c and c * cb == d:
    print("YES")
else:
    print("NO")
# Out:
# YES
